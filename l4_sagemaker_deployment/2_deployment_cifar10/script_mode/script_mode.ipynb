# %% [markdown]
# # Exercise: Script Mode in SageMaker using CIFAR-10 Dataset

# %%
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role

# %%
# TODO: Include the hyperparameters your script will need over here.
hyperparameters = {"epochs": "2", "batch-size": "32", "test-batch-size": "100", "lr": "0.001"}

# TODO: Create your estimator here. You can use Pytorch or any other framework.
estimator = PyTorch(
    entry_point="scripts/pytorch_cifar.py",
    base_job_name="sagemaker-script-mode",
    role=get_execution_role(),
    instance_count=1,
    instance_type="ml.m5.large",
    hyperparameters=hyperparameters,
    framework_version="1.8",
    py_version="py36",
)

# %%
#TODO: Start Training
estimator.fit(wait=True)
# Out:
# 2023-02-03 03:35:30 Starting - Starting the training job...
# 2023-02-03 03:36:00 Starting - Preparing the instances for trainingProfilerReport-1675395330: InProgress
# ......
# 2023-02-03 03:36:54 Downloading - Downloading input data...
# 2023-02-03 03:37:29 Training - Downloading the training image......
# 2023-02-03 03:38:29 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-02-03 03:38:29,684 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-02-03 03:38:29,687 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-02-03 03:38:29,696 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-02-03 03:38:29,698 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-02-03 03:38:29,865 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-02-03 03:38:29,878 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-02-03 03:38:29,889 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-02-03 03:38:29,898 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": "32",
#         "epochs": "2",
#         "lr": "0.001",
#         "test-batch-size": "100"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-script-mode-2023-02-03-03-35-30-208",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-145975612560/sagemaker-script-mode-2023-02-03-03-35-30-208/source/sourcedir.tar.gz",
#     "module_name": "pytorch_cifar",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "pytorch_cifar.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":"32","epochs":"2","lr":"0.001","test-batch-size":"100"}
# SM_USER_ENTRY_POINT=pytorch_cifar.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=pytorch_cifar
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-145975612560/sagemaker-script-mode-2023-02-03-03-35-30-208/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":"32","epochs":"2","lr":"0.001","test-batch-size":"100"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-script-mode-2023-02-03-03-35-30-208","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-145975612560/sagemaker-script-mode-2023-02-03-03-35-30-208/source/sourcedir.tar.gz","module_name":"pytorch_cifar","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"},"user_entry_point":"pytorch_cifar.py"}
# SM_USER_ARGS=["--batch-size","32","--epochs","2","--lr","0.001","--test-batch-size","100"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH-SIZE=32
# SM_HP_EPOCHS=2
# SM_HP_LR=0.001
# SM_HP_TEST-BATCH-SIZE=100
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 pytorch_cifar.py --batch-size 32 --epochs 2 --lr 0.001 --test-batch-size 100
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
# Extracting ../data/cifar-10-python.tar.gz to ../data
# [2023-02-03 03:38:35.431 algo-1:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-02-03 03:38:35.607 algo-1:27 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-02-03 03:38:35.608 algo-1:27 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-02-03 03:38:35.608 algo-1:27 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-02-03 03:38:35.609 algo-1:27 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2023-02-03 03:38:35.610 algo-1:27 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-02-03 03:38:35.615 algo-1:27 INFO hook.py:591] name:conv1.weight count_params:864
# [2023-02-03 03:38:35.615 algo-1:27 INFO hook.py:591] name:conv1.bias count_params:32
# [2023-02-03 03:38:35.615 algo-1:27 INFO hook.py:591] name:conv2.weight count_params:18432
# [2023-02-03 03:38:35.615 algo-1:27 INFO hook.py:591] name:conv2.bias count_params:64
# [2023-02-03 03:38:35.615 algo-1:27 INFO hook.py:591] name:fc1.weight count_params:1605632
# [2023-02-03 03:38:35.615 algo-1:27 INFO hook.py:591] name:fc1.bias count_params:128
# [2023-02-03 03:38:35.615 algo-1:27 INFO hook.py:591] name:fc2.weight count_params:1280
# [2023-02-03 03:38:35.615 algo-1:27 INFO hook.py:591] name:fc2.bias count_params:10
# [2023-02-03 03:38:35.615 algo-1:27 INFO hook.py:593] Total Trainable Params: 1626442
# [2023-02-03 03:38:35.616 algo-1:27 INFO hook.py:425] Monitoring the collections: losses
# [2023-02-03 03:38:35.618 algo-1:27 INFO hook.py:488] Hook is writing from the hook with pid: 27
# Train Epoch: 1 [0/50000 (0%)]#011Loss: 2.316089
# Train Epoch: 1 [3200/50000 (6%)]#011Loss: 2.304525
# Train Epoch: 1 [6400/50000 (13%)]#011Loss: 2.297701
# Train Epoch: 1 [9600/50000 (19%)]#011Loss: 2.318800
# Train Epoch: 1 [12800/50000 (26%)]#011Loss: 2.290138
# Train Epoch: 1 [16000/50000 (32%)]#011Loss: 2.305547
# Train Epoch: 1 [19200/50000 (38%)]#011Loss: 2.301939
# Train Epoch: 1 [22400/50000 (45%)]#011Loss: 2.292011
# Train Epoch: 1 [25600/50000 (51%)]#011Loss: 2.279472
# Train Epoch: 1 [28800/50000 (58%)]#011Loss: 2.303233
# Train Epoch: 1 [32000/50000 (64%)]#011Loss: 2.285724
# Train Epoch: 1 [35200/50000 (70%)]#011Loss: 2.291889
# Train Epoch: 1 [38400/50000 (77%)]#011Loss: 2.279906
# Train Epoch: 1 [41600/50000 (83%)]#011Loss: 2.270181
# Train Epoch: 1 [44800/50000 (90%)]#011Loss: 2.268280
# Train Epoch: 1 [48000/50000 (96%)]#011Loss: 2.276674
# Test set: Average loss: 2.2801, Accuracy: 1508/10000 (15%)
# Train Epoch: 2 [0/50000 (0%)]#011Loss: 2.270309
# Train Epoch: 2 [3200/50000 (6%)]#011Loss: 2.290131
# Train Epoch: 2 [6400/50000 (13%)]#011Loss: 2.254817
# Train Epoch: 2 [9600/50000 (19%)]#011Loss: 2.291001
# Train Epoch: 2 [12800/50000 (26%)]#011Loss: 2.243320
# Train Epoch: 2 [16000/50000 (32%)]#011Loss: 2.279521
# Train Epoch: 2 [19200/50000 (38%)]#011Loss: 2.295417
# Train Epoch: 2 [22400/50000 (45%)]#011Loss: 2.264769
# Train Epoch: 2 [25600/50000 (51%)]#011Loss: 2.249330
# Train Epoch: 2 [28800/50000 (58%)]#011Loss: 2.296869
# Train Epoch: 2 [32000/50000 (64%)]#011Loss: 2.243685
# Train Epoch: 2 [35200/50000 (70%)]#011Loss: 2.256683
# Train Epoch: 2 [38400/50000 (77%)]#011Loss: 2.263444
# Train Epoch: 2 [41600/50000 (83%)]#011Loss: 2.201081
# Train Epoch: 2 [44800/50000 (90%)]#011Loss: 2.225540
# Train Epoch: 2 [48000/50000 (96%)]#011Loss: 2.273544
#
# 2023-02-03 03:42:46 Uploading - Uploading generated training modelTest set: Average loss: 2.2421, Accuracy: 1923/10000 (19%)
# #015  0%|          | 0/170498071 [00:00<?, ?it/s]#015  0%|          | 839680/170498071 [00:00<00:20, 8396727.93it/s]#015  5%|▌         | 8615936/170498071 [00:00<00:03, 49186314.59it/s]#015 12%|█▏        | 19767296/170498071 [00:00<00:01, 77641174.15it/s]#015 18%|█▊        | 30853120/170498071 [00:00<00:01, 90753215.82it/s]#015 25%|██▍       | 42317824/170498071 [00:00<00:01, 99366493.13it/s]#015 31%|███       | 52880384/170498071 [00:00<00:01, 101491374.12it/s]#015 37%|███▋      | 63848448/170498071 [00:00<00:01, 104165260.81it/s]#015 44%|████▍     | 74979328/170498071 [00:00<00:00, 106437132.90it/s]#015 50%|█████     | 85624832/170498071 [00:00<00:00, 106434591.90it/s]#015 57%|█████▋    | 96728064/170498071 [00:01<00:00, 107841842.14it/s]#015 63%|██████▎   | 107584512/170498071 [00:01<00:00, 108045191.86it/s]#015 69%|██████▉   | 118389760/170498071 [00:01<00:00, 107881593.69it/s]#015 76%|███████▌  | 129632256/170498071 [00:01<00:00, 109250067.27it/s]#015 82%|████████▏ | 140558336/170498071 [00:01<00:00, 108509153.23it/s]#015 89%|████████▉ | 151463936/170498071 [00:01<00:00, 108672355.92it/s]#015 95%|█████████▌| 162488320/170498071 [00:01<00:00, 109133396.59it/s]#015170499072it [00:01, 101487524.42it/s]
# 2023-02-03 03:42:41,759 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2023-02-03 03:43:10 Completed - Training job completed
# Training seconds: 363
# Billable seconds: 363
